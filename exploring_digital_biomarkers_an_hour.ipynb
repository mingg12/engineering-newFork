# %% [markdown]
# # Exploring dataset (an hour)

# %% [markdown]
# Checking various types of data for an hour from 18:00 (2020-02-13), the food(Berry Smoothie) intake time.

# %%
import pandas as pd

# %% [markdown]
# ## Food Log

# %%
fl001_df = pd.read_csv('./big-ideas-lab-glycemic-variability-and-wearable-device-data-1.1.2/001/Food_Log_001.csv')

# %%
fl001_df.head(10)
# Out:
#          date      time           time_begin  time_end  \
# 0  2020-02-13  18:00:00  2020-02-13 18:00:00       NaN
# 1  2020-02-13  20:30:00  2020-02-13 20:30:00       NaN
# 2  2020-02-13  20:30:00  2020-02-13 20:30:00       NaN
# 3  2020-02-14  07:10:00  2020-02-14 07:10:00       NaN
# 4  2020-02-14  07:10:00  2020-02-14 07:10:00       NaN
# 5  2020-02-14  09:38:00  2020-02-14 09:38:00       NaN
# 6  2020-02-14  12:38:00  2020-02-14 12:38:00       NaN
# 7  2020-02-14  12:38:00  2020-02-14 12:38:00       NaN
# 8  2020-02-14  19:30:00  2020-02-14 19:30:00       NaN
# 9  2020-02-14  20:00:00  2020-02-14 20:00:00       NaN
#
#                                 logged_food  amount         unit  \
# 0                            Berry Smoothie   20.00  fluid ounce
# 1                               Chicken Leg    1.00          NaN
# 2                                 Asparagus    4.00          NaN
# 3             Natrel Lactose Free 2 Percent    8.00  fluid ounce
# ...

# %% [markdown]
# ## Dexcom

# %%
dexcom001_df = pd.read_csv('./big-ideas-lab-glycemic-variability-and-wearable-device-data-1.1.2/001/Dexcom_001.csv')

# %%
dexcom001_df.head(30)
# Out:
#     Index Timestamp (YYYY-MM-DDThh:mm:ss)         Event Type    Event Subtype  \
# 0       1                             NaN          FirstName              NaN
# 1       2                             NaN           LastName              NaN
# 2       3                             NaN  PatientIdentifier              NaN
# 3       4                             NaN        DateOfBirth              NaN
# 4       5                             NaN             Device              NaN
# 5       6                             NaN              Alert             Fall
# 6       7                             NaN              Alert             High
# 7       8                             NaN              Alert              Low
# 8       9                             NaN              Alert      Signal Loss
# 9      10                             NaN              Alert             Rise
# 10     11                             NaN              Alert       Urgent Low
# ...

# %%
dexcom001_df['Timestamp (YYYY-MM-DDThh:mm:ss)']=pd.to_datetime(dexcom001_df['Timestamp (YYYY-MM-DDThh:mm:ss)'])

# %%
dexcom001_df[(dexcom001_df['Timestamp (YYYY-MM-DDThh:mm:ss)'] >= '2020-02-13 18:00:00') & (dexcom001_df['Timestamp (YYYY-MM-DDThh:mm:ss)'] <= '2020-02-13 19:00:00')].plot(y='Glucose Value (mg/dL)')
# Out:
# <Axes: >

# %%
dexcom001_df[(dexcom001_df['Timestamp (YYYY-MM-DDThh:mm:ss)'] >= '2020-02-14 00:00:00') & (dexcom001_df['Timestamp (YYYY-MM-DDThh:mm:ss)'] <= '2020-02-14 23:59:59')].head()
# Out:
#     Index Timestamp (YYYY-MM-DDThh:mm:ss) Event Type Event Subtype  \
# 92     93             2020-02-14 00:03:32        EGV           NaN
# 93     94             2020-02-14 00:08:32        EGV           NaN
# 94     95             2020-02-14 00:13:31        EGV           NaN
# 95     96             2020-02-14 00:18:31        EGV           NaN
# 96     97             2020-02-14 00:23:32        EGV           NaN
#
#    Patient Info Device Info Source Device ID  Glucose Value (mg/dL)  \
# 92          NaN         NaN        iPhone G6                  111.0
# 93          NaN         NaN        iPhone G6                  110.0
# 94          NaN         NaN        iPhone G6                  110.0
# 95          NaN         NaN        iPhone G6                  110.0
# 96          NaN         NaN        iPhone G6                  111.0
#
#     Insulin Value (u)  Carb Value (grams) Duration (hh:mm:ss)  \
# 92                NaN                 NaN                 NaN
# ...

# %%
dexcom001_df[(dexcom001_df['Timestamp (YYYY-MM-DDThh:mm:ss)'] >= '2020-02-14 00:00:00') & (dexcom001_df['Timestamp (YYYY-MM-DDThh:mm:ss)'] <= '2020-02-14 23:59:59')].plot(y='Glucose Value (mg/dL)')
# Out:
# <Axes: >

# %% [markdown]
# ## ACC

# %%
acc001_df = pd.read_csv('./big-ideas-lab-glycemic-variability-and-wearable-device-data-1.1.2/001/ACC_001.csv')

# %%
acc001_df.head()
# Out:
#                      datetime   acc_x   acc_y   acc_z
# 0  2020-02-13 15:28:50.000000   -34.0    17.0    55.0
# 1  2020-02-13 15:28:50.031250   -34.0    17.0    52.0
# 2  2020-02-13 15:28:50.062500   -34.0    19.0    51.0
# 3  2020-02-13 15:28:50.093750   -36.0    18.0    51.0
# 4  2020-02-13 15:28:50.125000   -35.0    17.0    52.0

# %%
acc001_df['datetime']=pd.to_datetime(acc001_df['datetime'])

# %%
acc001_df['datetime'].dtype
# Out:
# dtype('<M8[ns]')

# %%
acc001_df[(acc001_df['datetime'] >= '2020-02-13 18:00:00') & (acc001_df['datetime'] <= '2020-02-13 19:00:00')].plot(y=[' acc_x', ' acc_y', ' acc_z'])
# Out:
# <Axes: >

# %%
acc001_df[(acc001_df['datetime'] >= '2020-02-13 18:00:00') & (acc001_df['datetime'] <= '2020-02-13 19:00:00')].set_index('datetime').resample('5Min').first()
# Out:
#                       acc_x   acc_y   acc_z
# datetime
# 2020-02-13 18:00:00    62.0    10.0     1.0
# 2020-02-13 18:05:00    -4.0    21.0    71.0
# 2020-02-13 18:10:00     7.0    -3.0    68.0
# 2020-02-13 18:15:00     9.0    47.0    41.0
# 2020-02-13 18:20:00    45.0    -3.0    45.0
# 2020-02-13 18:25:00   -16.0    56.0    27.0
# 2020-02-13 18:30:00   -23.0    31.0    36.0
# 2020-02-13 18:35:00     2.0    58.0    26.0
# 2020-02-13 18:40:00     2.0    62.0    13.0
# 2020-02-13 18:45:00    18.0   -34.0    38.0
# 2020-02-13 18:50:00    13.0   -59.0     8.0
# 2020-02-13 18:55:00     5.0   -62.0    16.0
# 2020-02-13 19:00:00    10.0    54.0    33.0

# %% [markdown]
# ## EDA

# %%
eda001_df = pd.read_csv('./big-ideas-lab-glycemic-variability-and-wearable-device-data-1.1.2/001/EDA_001.csv')

# %%
eda001_df.head()
# Out:
#                   datetime       eda
# 0  2020-02-13 15:28:50.000  0.000000
# 1  2020-02-13 15:28:50.250  0.001281
# 2  2020-02-13 15:28:50.500  0.026905
# 3  2020-02-13 15:28:50.750  0.028186
# 4  2020-02-13 15:28:51.000  0.029467

# %%
eda001_df['datetime']=pd.to_datetime(eda001_df['datetime'])

# %%
eda001_df[(eda001_df['datetime'] >= '2020-02-13 18:00:00') & (eda001_df['datetime'] <= '2020-02-13 19:00:00')].plot(y=' eda')
# Out:
# <Axes: >

# %% [markdown]
# ## BVP

# %%
bvp001_df = pd.read_csv('./big-ideas-lab-glycemic-variability-and-wearable-device-data-1.1.2/001/BVP_001.csv')

# %%
bvp001_df.head()
# Out:
#                      datetime   bvp
# 0  2020-02-13 15:28:50.000000  -0.0
# 1  2020-02-13 15:28:50.015625  -0.0
# 2  2020-02-13 15:28:50.031250  -0.0
# 3  2020-02-13 15:28:50.046875  -0.0
# 4  2020-02-13 15:28:50.062500  -0.0

# %%
bvp001_df['datetime']=pd.to_datetime(bvp001_df['datetime'])

# %%
bvp001_df[(bvp001_df['datetime'] >= '2020-02-13 18:00:00') & (bvp001_df['datetime'] <= '2020-02-13 19:00:00')].plot(y=' bvp')
# Out:
# <Axes: >

# %% [markdown]
# ## HR

# %%
hr001_df = pd.read_csv('./big-ideas-lab-glycemic-variability-and-wearable-device-data-1.1.2/001/HR_001.csv')

# %%
hr001_df.head()
# Out:
#         datetime    hr
# 0  2/13/20 15:29  94.0
# 1  2/13/20 15:29  99.0
# 2  2/13/20 15:29  94.0
# 3  2/13/20 15:29  82.5
# 4  2/13/20 15:29  82.6

# %%
hr001_df['datetime']=pd.to_datetime(hr001_df['datetime'], format='%m/%d/%y %H:%M')

# %%
hr001_df[(hr001_df['datetime'] >= '2020-02-13 18:00:00') & (hr001_df['datetime'] <= '2020-02-13 19:00:00')].plot(y=' hr')
# Out:
# <Axes: >

# %% [markdown]
# ## IBI

# %%
ibi001_df = pd.read_csv('./big-ideas-lab-glycemic-variability-and-wearable-device-data-1.1.2/001/IBI_001.csv')

# %%
ibi001_df.head()
# Out:
#                      datetime       ibi
# 0  2020-02-13 15:33:22.059328  0.828163
# 1  2020-02-13 15:33:22.934368  0.875040
# 2  2020-02-13 15:34:21.593303  0.984420
# 3  2020-02-13 15:34:22.483969  0.890666
# 4  2020-02-13 15:34:23.421512  0.937543

# %%
ibi001_df['datetime']=pd.to_datetime(ibi001_df['datetime'])

# %%
ibi001_df[(ibi001_df['datetime'] >= '2020-02-13 18:00:00') & (ibi001_df['datetime'] <= '2020-02-13 19:00:00')].plot(y=' ibi')
# Out:
# <Axes: >

# %% [markdown]
# ## TEMP

# %%
temp001_df = pd.read_csv('./big-ideas-lab-glycemic-variability-and-wearable-device-data-1.1.2/001/TEMP_001.csv')

# %%
temp001_df.head()
# Out:
#                   datetime   temp
# 0  2020-02-13 15:28:50.000  30.21
# 1  2020-02-13 15:28:50.250  30.21
# 2  2020-02-13 15:28:50.500  30.21
# 3  2020-02-13 15:28:50.750  30.21
# 4  2020-02-13 15:28:51.000  30.21

# %%
temp001_df['datetime']=pd.to_datetime(temp001_df['datetime'])

# %%
temp001_df[(temp001_df['datetime'] >= '2020-02-13 18:00:00') & (temp001_df['datetime'] <= '2020-02-13 19:00:00')].plot(y=' temp')
# Out:
# <Axes: >
